# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict,Annotated
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from pydantic import BaseModel, Field
import operator

load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model="openai/gpt-oss-120b"
)

# %%
class EvaluationSchema(BaseModel):

    feedback: str = Field(description='Detailed feedbackfor the essay')
    score: float = Field(description='Score out of 10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
structured_model.invoke(essay)
# Out:
# EvaluationSchema(feedback='**Overall Assessment**\nThe essay provides a clear, well‑structured overview of the promises and perils of artificial intelligence. It follows a logical progression—introducing AI, outlining benefits, discussing drawbacks, describing applications, and concluding with challenges and future directions. The language is accessible and the points are generally supported with relevant examples.\n\n**Strengths**\n1. **Structure & Organization** – The use of headings (Benefits, Drawbacks, Applications, Challenges) makes the piece easy to navigate and helps the reader follow the argument.\n2. **Breadth of Coverage** – You touch on a wide range of sectors (healthcare, finance, transportation, education, entertainment) which demonstrates an understanding of AI’s pervasive impact.\n3. **Concrete Examples** – References to Siri, Alexa, Walmart, Amazon, and facial‑recognition bias give the discussion real‑world grounding.\n4. **Balanced Perspective** – The essay acknowledges both the transformative potential of AI and the serious societal risks, fulfilling the "double‑edged sword" theme.\n\n**Areas for Improvement**\n1. **Depth of Analysis** – While the essay mentions many applications, the discussion often stays at a surface level. For a higher‑level essay, dive deeper into a few case studies (e.g., how AI improves diagnostic accuracy in radiology, or the specific economic impact of autonomous trucks).\n2. **Evidence & Citation** – Assertions such as "AI‑powered chatbots have reduced workload" or "AI has helped Walmart optimize supply chains" would be stronger with quantitative data or citations (e.g., a study showing a 30\u202f% reduction in call‑center volume).\n3. **Critical Nuance** – The drawbacks section could benefit from more nuance. For example, instead of stating that "AI will lead to the loss of millions of jobs," discuss how automation can also create new roles and the importance of reskilling.\n4. **Clarity & Conciseness** – Some sentences are wordy or repetitive (e.g., the conclusion restates earlier points verbatim). Tightening the prose would improve readability.\n5. **Stylistic Consistency** – The essay shifts between present‑tense narrative and occasional future‑tense speculation. Maintaining a consistent tense helps maintain flow.\n6. **Ethical & Governance Details** – The challenges section mentions the need for transparency, explainability, and accountability but could elaborate on concrete frameworks (e.g., EU AI Act, algorithmic impact assessments) and who should be responsible for enforcement.\n7. **Proofreading** – Minor grammatical issues (e.g., missing articles, inconsistent pluralization) are present. A quick proofread would eliminate these distractions.\n\n**Specific Recommendations**\n- **Add Data**: Include a statistic such as "AI‑driven diagnostic tools have reduced error rates by X\u202f% in dermatology" to substantiate claims.\n- **Expand One Application**: Choose one sector (e.g., healthcare) and explore both a benefit (personalized medicine) and a risk (data privacy) in more depth.\n- **Address Counter‑Arguments**: Briefly discuss arguments that AI could augment rather than replace workers, and propose policies for workforce transition.\n- **Conclude with a Call‑to‑Action**: End with a specific recommendation—e.g., establishing interdisciplinary AI ethics boards at the national level.\n\n**Score (out of 10)**\nGiven the essay’s solid organization, breadth of coverage, and clear writing, but noting the need for deeper analysis, supporting evidence, and tighter prose, I assign a score of **7.5/10**.\n\n**Final Note**\nYou have a strong foundation. By enriching the analysis with data, sharpening the argumentation, and polishing the language, the essay can move from good to excellent.', score=7.5)

# %%
essay = """'**The Rise of Artificial Intelligence: A Double-Edged Sword**\n\nArtificial Intelligence (AI) has revolutionized the way we live, work, and interact with each other. From virtual assistants like Siri and Alexa to self-driving cars and intelligent personal assistants, AI has become an integral part of our daily lives. However, the rapid advancement of AI has also raised concerns about its potential impact on society, economy, and individual freedoms. In this essay, we will explore the benefits and drawbacks of AI, its applications, and the challenges it poses to humanity.\n\n**The Benefits of AI**\n\nAI has numerous benefits that have improved the quality of life for millions of people worldwide. One of the most significant advantages of AI is its ability to automate repetitive and mundane tasks, freeing up human resources to focus on more complex and creative tasks. For instance, AI-powered chatbots have reduced the workload of customer service representatives, allowing them to focus on more complex issues and provide better customer experiences. AI has also improved the accuracy and efficiency of healthcare services, enabling medical professionals to diagnose diseases more accurately and develop personalized treatment plans.\n\nAnother significant benefit of AI is its ability to analyze vast amounts of data, providing insights that can inform business decisions and drive innovation. For example, AI-powered data analytics has helped companies like Walmart and Amazon optimize their supply chains, reducing costs and improving customer satisfaction. AI has also transformed the field of education, enabling personalized learning experiences and improving student outcomes.\n\n**The Drawbacks of AI**\n\nWhile AI has numerous benefits, it also poses significant risks to society, economy, and individual freedoms. One of the most significant concerns is the potential loss of jobs due to automation. As AI takes over routine and repetitive tasks, many workers may find themselves replaced by machines, leading to unemployment and economic instability. For instance, the rise of self-driving cars may lead to the loss of millions of jobs in the transportation sector.\n\nAnother significant concern is the potential for AI to perpetuate biases and prejudices. AI systems are trained on vast amounts of data, which can reflect existing societal biases and prejudices. For example, AI-powered facial recognition systems have been shown to be less accurate for people of color, highlighting the need for more inclusive and diverse training data.\n\n**The Applications of AI**\n\nAI has numerous applications across various industries, including healthcare, finance, transportation, and education. In healthcare, AI is being used to develop personalized treatment plans, improve disease diagnosis, and reduce medical errors. In finance, AI is being used to detect and prevent financial crimes, such as money laundering and terrorist financing.\n\nIn transportation, AI is being used to develop self-driving cars and improve traffic management systems. In education, AI is being used to develop personalized learning experiences, improve student outcomes, and reduce teacher workload. AI is also being used in the field of entertainment, creating more realistic and immersive experiences for consumers.\n\n**Challenges and Future Directions**\n\nAs AI continues to advance, it poses significant challenges to humanity. One of the most significant challenges is ensuring that AI is developed and used in a way that benefits society as a whole. This requires a multidisciplinary approach, involving experts from various fields, including computer science, philosophy, ethics, and sociology.\n\nAnother significant challenge is ensuring that AI is transparent, explainable, and accountable. As AI becomes more complex and autonomous, it is essential that we can understand how it makes decisions and take responsibility for its actions.\n\nIn conclusion, AI is a double-edged sword that has the potential to revolutionize our lives, but also poses significant risks to society, economy, and individual freedoms. While AI has numerous benefits, including improved efficiency, accuracy, and decision-making, it also has drawbacks, including the potential loss of jobs, perpetuation of biases, and lack of transparency and accountability.\n\nAs AI continues to advance, it is essential that we address these challenges and develop more inclusive, transparent, and responsible AI systems. This requires a collaborative effort from governments, industries, and individuals to ensure that AI is developed and used in a way that benefits humanity as a whole.'"""

# %%
prompt = f'Evalute the language quality of the essay and provide a feedback and assign a score out of 10 \n {essay}'

# %%
class UPSCState(TypedDict):

    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]  #[]+[] same as list concatenation we are using operator.add
    avg_score: float

# %%
def evaluate_language(state: UPSCState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: UPSCState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: UPSCState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: UPSCState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)

# edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')

graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation', END)

workflow = graph.compile()

# %%
workflow

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
# Execute the workflow 

intial_state = {
    'essay': essay2
}

workflow.invoke(intial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'The essay conveys enthusiasm about AI in India but suffers from numerous language‑related problems that make it difficult to read and understand. \n\n**Grammar and Mechanics**: \n- Frequent subject‑verb agreement errors (e.g., "India also want become big", "If work hard, India can go top").\n- Inconsistent verb tenses and missing auxiliaries ("India have many good", "We teach AI and make sure AI not bad").\n- Incorrect plural forms and article usage ("many engine‑ear", "the AI time in India have many hope").\n- Numerous spelling mistakes and incomplete words ("Intel… something", "doctor place", "farm" instead of "farmers").\n- Punctuation is almost absent, leading to run‑on sentences.\n\n**Vocabulary and Word Choice**:\n- The writer repeatedly uses informal, colloquial phrasing ("AI thing", "big bad thing happen") that is unsuitable for an essay.\n- Many nouns are used incorrectly or are vague ("engine‑ear", "good IT peoples").\n- Repetition of simple words ("good", "big", "AI") without synonyms reduces lexical variety.\n\n**Coherence and Organization**:\n- The essay lacks clear paragraph structure; ideas are loosely strung together.\n- Transitions between points are weak, making the logical flow hard to follow.\n- The conclusion restates the main idea but does not summarise the arguments presented earlier.\n\n**Overall Effectiveness**:\n- The central argument – that AI offers both opportunities and risks for India and that inclusive, regulated development is needed – is clear, but the language barriers prevent the message from being communicated persuasively.\n\n**Recommendations**:\n1. Proofread for basic grammar, subject‑verb agreement, and article usage.\n2. Expand the vocabulary and replace informal phrases with academic alternatives.\n3. Organize the essay into clear paragraphs: introduction, benefits (agriculture, health, education, governance), challenges (digital divide, job displacement, privacy), and a concluding call to action.\n4. Use transitional words (however, moreover, therefore) to improve flow.\n5. Incorporate concrete examples or statistics to support claims.\n\n**Score**: 3.5/10 – the essay shows an understandable intent but the language quality is substantially below academic standards.',
#  'analysis_feedback': 'The essay shows a basic awareness of AI’s potential impact on India, mentioning several sectors (agriculture, health, education, governance) and flagging key challenges such as digital divide, job displacement, and privacy. However, the analysis remains superficial. It does not provide concrete examples, data, or nuanced discussion of how AI could be implemented, nor does it explore policy mechanisms, economic implications, or the interplay between stakeholders in any depth. The argument is largely a list of ideas rather than a critical examination, and the essay is hindered by numerous language and structural issues that obscure its points. To improve, the writer should develop each theme with specific case studies or statistics, compare India’s position with other countries, discuss concrete policy measures (e.g., data protection laws, reskilling programs), and organize the essay with a clear thesis, supporting arguments, and a conclusion.\n\nOverall, the essay demonstrates limited analytical depth and would benefit from more evidence‑based reasoning and clearer organization.',
#  'clarity_feedback': 'The essay conveys a clear overall message—that AI presents both opportunities and risks for India and that inclusive, well‑regulated development is essential. However, the clarity of thought is hampered by several issues:\n\n1. **Structure and Organization** – The piece jumps between ideas without clear transitions. It would benefit from distinct sections (e.g., introduction, opportunities, challenges, recommendations, conclusion) and logical sequencing within each.\n\n2. **Coherence of Arguments** – While the main points (benefits in agriculture, health, education, governance; challenges of digital divide, job loss, privacy) are present, they are introduced in a fragmented way. Some sentences repeat ideas without adding depth, and the link between points is often implicit rather than explicit.\n\n3. **Precision of Language** – Frequent grammatical errors, missing articles, and awkward phrasing (“new tech call Artificial Intel… something”, “engine‑ear”, “doctor place”) distract the reader and obscure meaning. More precise vocabulary would improve comprehension.\n\n4. **Depth of Analysis** – The essay mentions important concerns (digital exclusion, unemployment, data protection) but does not elaborate on how they could be mitigated beyond vague calls for “teaching AI” and “strong rules”. Providing concrete examples or policy suggestions would strengthen the argument.\n\n5. **Consistency and Tone** – The tone shifts between informal (“world say ‘good job India’”) and formal, which can confuse the reader about the intended audience.\n\n**Overall Assessment** – The essay demonstrates an understanding of the topic and a genuine concern for equitable AI development, but the lack of clear organization, grammatical accuracy, and depth reduces its clarity of thought.\n\n**Score (0‑10)**: 5.5 – The essay is understandable at a basic level but requires significant improvement to achieve clear, logical, and persuasive communication.',
#  'overall_feedback': '**Summarized Feedback**\n\n---\n\n### 1. Language & Mechanics  \n- **Grammar** – Frequent subject‑verb agreement errors, missing auxiliaries, inconsistent tenses, and incorrect article/plural usage.  \n- **Spelling & Punctuation** – Numerous misspellings, incomplete words, and almost no punctuation, resulting in run‑on sentences.  \n- **Vocabulary** – Over‑reliance on informal, colloquial phrasing (“AI thing”, “big bad thing happen”) and vague nouns (“engine‑ear”, “good IT peoples”). Repetition of simple words reduces lexical variety.  \n\n**Impact:** The language problems make the essay difficult to read and undermine the credibility of the argument.\n\n---\n\n### 2. Depth of Analysis  \n- **Scope** – Mentions key sectors (agriculture, health, education, governance) and challenges (digital divide, job loss, privacy) but stays at a superficial level.  \n- **Evidence** – Lacks concrete examples, data, case studies, or comparative context (e.g., how other countries handle AI).  \n- **Policy Discussion** – No detailed examination of specific policy tools (data‑protection laws, reskilling programs, regulatory frameworks).  \n\n**Impact:** The essay reads more like a checklist of ideas than a critical, evidence‑based analysis.\n\n---\n\n### 3. Clarity of Thought & Organization  \n- **Structure** – No clear paragraphing; ideas are jumbled with weak or missing transitions.  \n- **Coherence** – Main points are present but introduced in a fragmented way; some sentences repeat ideas without adding depth.  \n- **Tone** – Shifts between informal (“world say ‘good job India’”) and formal, confusing the intended audience.  \n\n**Impact:** The lack of logical sequencing and precise language obscures the central message.\n\n---\n\n### 4. Overall Effectiveness  \n- **Core Argument** – The thesis that AI offers both opportunities and risks for India and needs inclusive, regulated development is clear.  \n- **Communication** – Language barriers, shallow analysis, and poor organization prevent the argument from being persuasive.\n\n**Combined Scores**  \n- Language Quality: **3.5 / 10**  \n- Analytical Depth: **~4 / 10** (based on superficial treatment)  \n- Clarity of Thought: **5.5 / 10**  \n\n---\n\n### 5. Recommendations (Actionable)\n\n| Area | What to Do |\n|------|------------|\n| **Grammar & Mechanics** | Proofread for subject‑verb agreement, correct article/plural use, and add punctuation. Use a spell‑checker or grammar tool. |\n| **Vocabulary** | Replace informal phrasing with academic equivalents; vary word choice (e.g., “significant,” “transformative,” “challenges”). |\n| **Structure** | Organize into clear sections: <br>1. Introduction (thesis) <br>2. Opportunities (agri, health, education, governance) <br>3. Challenges (digital divide, employment, privacy) <br>4. Policy Recommendations <br>5. Conclusion (call to action). |\n| **Coherence** | Use transitional devices (however, moreover, therefore) to link ideas; ensure each paragraph focuses on a single point. |\n| **Depth of Analysis** | Support each claim with specific examples or statistics (e.g., “AI‑driven crop‑yield models have increased output by X% in Punjab”). Compare India’s AI trajectory with other nations. Discuss concrete policies: data‑protection legislation, national AI strategy, reskilling initiatives, public‑private partnerships. |\n| **Tone** | Maintain a consistent, formal academic tone throughout. |\n| **Proofreading** | After revisions, read the essay aloud or have a peer review to catch remaining errors. |\n\n---\n\n**Bottom Line:** The essay shows genuine enthusiasm and a correct high‑level understanding of AI’s relevance to India, but language errors, shallow analysis, and disorganized presentation severely limit its impact. Implement the above recommendations to raise the work to a credible, persuasive academic standard.',
#  'individual_scores': [3.5, 3.5, 5.5],
#  'avg_score': 4.166666666666667}
