# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str

    # NEW: tells workers what genre this is (prevents drift)
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"

    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query: int = Field(5, description="How many results to fetch per query (3–8).")


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 2) LLM
# -----------------------------
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    """
    Uses TavilySearchResults if installed and TAVILY_API_KEY is set.
    Returns list of dict with common fields. Note: published date is often missing.
    """
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}
# -----------------------------

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}


# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out
run("Write a blog on Self Attention")
# Out:
# ====================================================================================================
# TOPIC: Write a blog on Self Attention
# AS_OF: 2026-03-01 RECENCY_DAYS: 3650
# MODE: closed_book
# BLOG_KIND: explainer
# NEEDS_RESEARCH: False
# QUERIES: []
# EVIDENCE_COUNT: 0
# TASKS: 6
# SAVED_MD_CHARS: 15023
# ====================================================================================================
# {'topic': 'Write a blog on Self Attention',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Demystifying Self‑Attention: Theory, Code, and Practical Tips', audience='developer', tone='Professional and approachable, with concrete examples for engineers', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='What Self‑Attention Is and Why It Matters', goal='Explain the core intuition behind self‑attention and its role in modern deep‑learning models.', bullets=['Contrast self‑attention with traditional recurrent and convolutional layers in terms of information flow.', 'Describe the “query‑key‑value” metaphor and how each token attends to every other token.', 'Show a high‑level data‑flow diagram that maps input embeddings to attention‑weighted outputs.', 'Highlight real‑world use cases (e.g., language modeling, vision transformers, graph neural networks).'], target_words=220, tags=['conceptual', 'motivation'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Scaled Dot‑Product Self‑Attention: The Mathematics', goal='Derive the scaled dot‑product formulation and explain each component’s purpose.', bullets=['Write the core equation\u202f:\u202fAttention(Q,\u202fK,\u202fV)\u202f=\u202fsoftmax((QKᵀ)/√dₖ)\u202fV.', 'Explain why the scaling factor √dₖ stabilizes gradients for large hidden dimensions.', 'Show how the softmax creates a probability distribution over tokens and why it is essential for differentiability.', 'Derive the gradient of the attention output with respect to Q, K, and V to illustrate back‑propagation flow.', 'Discuss the effect of mask matrices (e.g., causal masks) on the softmax computation.'], target_words=260, tags=['math', 'derivation'], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='A Minimal PyTorch Implementation (MWE)', goal='Provide a concise, runnable code sketch that implements scaled dot‑product self‑attention from scratch.', bullets=['Create three linear layers to project input embeddings into Q, K, and V tensors.', 'Compute the scaled dot‑product, apply an optional mask, and run softmax.', 'Multiply the softmax scores by V and return the attention output.', 'Wrap the logic in a nn.Module class with a forward method that accepts a batch of sequences.', 'Validate the implementation by comparing its output to torch.nn.MultiheadAttention on a dummy tensor.'], target_words=300, tags=['code', 'pytorch', 'mwe'], requires_research=False, requires_citations=False, requires_code=True), Task(id=4, title='Multi‑Head Attention: Extending the Primitive', goal='Show how multiple attention heads are combined to enrich representation power.', bullets=['Explain why splitting the hidden dimension into h heads improves the model’s ability to capture diverse patterns.', 'Detail the steps: linear projections per head, independent attention, concatenation, and final linear projection.', 'Provide a schematic that maps the per‑head tensors back to the original hidden size.', 'Discuss head‑specific hyper‑parameters (e.g., different dropout rates) and when to use shared vs. independent projections.', 'Mention practical tricks: using torch.nn.MultiheadAttention, handling variable sequence lengths, and caching keys/values for inference.'], target_words=250, tags=['architecture', 'multi‑head'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Performance and Cost Considerations', goal='Identify the computational and memory trade‑offs of self‑attention and outline strategies to mitigate them.', bullets=['Analyze the O(N²\u202f·\u202fd) time and memory complexity where N is sequence length and d is hidden size.', 'Show how sequence length dominates cost by profiling a forward pass on a GPU (e.g., using torch.autograd.profiler).', 'Introduce low‑rank and sparse approximations (e.g., Linformer, Performer) and when they are beneficial.', 'Explain mixed‑precision (FP16/ BF16) and kernel fusion techniques that reduce latency on modern accelerators.', 'Provide a rule‑of ...
#  'as_of': '2026-03-01',
#  'recency_days': 3650,
#  'sections': [(1,
#    '## What Self‑Attention Is and Why It Matters\n\nTraditional recurrent networks pass a hidden state sequentially, so information from token\u202f*i* reaches token\u202f*j* only after *i\u202f→\u202fi+1\u202f→\u202f…\u202f→\u202fj* steps. Convolutional layers aggregate locally with a fixed receptive field; distant tokens influence each other only after many stacked layers. Self‑attention removes both constraints: every token can directly read a weighted sum of all other token representations in a single layer, providing a global receptive field with constant depth.\n\nThe mechanism is often described with the **query‑key‑value** metaphor. For each token we compute three vectors—*query*\u202f*Q*, *key*\u202f*K*, and *value*\u202f*V*—by linear projections of the same embedding. The attention weight between token\u202f*i* and token\u202f*j* is proportional to the similarity of *Q₍i₎* and *K₍j₎* (typically a scaled dot‑product). Multiplying these weights by the corresponding *V₍j₎* and summing yields the output for token\u202f*i*, meaning each token attends to every other token.\n\n```mermaid\ngraph LR\n    Input[Input Embeddings] -->|Linear proj.| Q[Queries]\n    Input -->|Linear proj.| K[Keys]\n    Input -->|Linear proj.| V[Values]\n    Q -->|Dot‑product| Sim[Similarity Matrix]\n    K -->|Dot‑product| Sim\n    Sim -->|Softmax| Weights[Attention Weights]\n    Weights -->|Weighted sum| O[Attention‑Weighted Output]\n    V --> O\n    O --> Output[Next Layer Input]\n```\n\nSelf‑attention quickly became the backbone of modern models. In **language modeling**, Transformers replace RNNs to capture long‑range dependencies, enabling large‑scale text generation. **Vision Transformers** treat image patches as tokens, achieving state‑of‑the‑art classification and detection without convolutions. **Graph neural networks** such as Graph Attention Networks use attention to weigh neighboring node features, improving relational reasoning on irregular structures.'),
#   (2,
#    '## Scaled Dot‑Product Self‑Attention: The Mathematics\n\nThe heart of the Transformer’s attention mechanism is the **scaled dot‑product** operation:  \n\n\\[\n\\text{Attention}(Q, K, V) = \\text{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}}\\right)V\n\\]\n\nwhere \\(Q\\in\\mathbb{R}^{n\\times d_k}\\), \\(K\\in\\mathbb{R}^{n\\times d_k}\\), and \\(V\\in\\mathbb{R}^{n\\times d_v}\\) are the query, key, and value matrices for a sequence of \\(n\\) tokens, and \\(d_k\\) is the dimensionality of the key/query vectors.\n\n### Why scale by \\(\\sqrt{d_k}\\)?\n\nEach entry of \\(QK^{\\top}\\) is a sum of \\(d_k\\) products of independent random variables. Its variance grows linearly with \\(d_k\\). Without scaling, large \\(d_k\\) push the dot‑product magnitudes into a region where the softmax saturates (extreme values → near‑zero gradients). Dividing by \\(\\sqrt{d_k}\\) normalizes the variance to roughly 1, keeping the softmax inputs in a regime where gradients remain stable and training converges faster.\n\n### Softmax as a probability distribution\n\nThe softmax transforms the scaled scores \\(s_{ij} = (QK^{\\top})_{ij}/\\sqrt{d_k}\\) into non‑negative weights that sum to one:\n\n\\[\n\\alpha_{ij} = \\frac{\\exp(s_{ij})}{\\sum_{l=1}^{n}\\exp(s_{il})}\n\\]\n\nThus each row \\(\\alpha_i\\) is a categorical distribution over all tokens, indicating how much token \\(i\\) attends to token \\(j\\). Because softmax is differentiable everywhere, gradients can flow from the loss back through the attention weights to \\(Q\\), \\(K\\), and \\(V\\).\n\n### Gradient flow\n\nLet \\(A = \\text{softmax}(S)V\\) with \\(S = QK^{\\top}/\\sqrt{d_k}\\). For a loss \\(\\mathcal{L}\\),\n\n\\[\n\\frac{\\partial \\mathcal{L}}{\\partial V} = \\alpha^{\\top}\\frac{\\partial \\mathcal{L}}{\\partial A},\n\\qquad\n\\frac{\\partial \\mathcal{L}}{\\partial S} = \\left(\\frac{\\partial \\mathcal{L}}{\\partial A}V^{\\top}\\right) \\odot \\alpha \\odot (I - \\alpha),\n\\]\n\nwhere \\(\\odot\\) denotes element‑wise multiplication and the term \\(\\alpha \\odot (I - \\alpha)\\) is the Jacobian of the softmax. Finally,\n\n\\[\n\\frac{\\partial \\mathcal{L}}{\\partial Q} = \\frac{1}{\\sqrt{d_k}}\\,\\frac{\\partial \\mathcal{L}}{\\partial S}K,\n\\qquad\n\\frac{\\partial \\mathcal{L}}{\\partial K} = \\frac{1}{\\sqrt{d_k}}\\,Q^{\\top}\\frac{\\partial \\mathcal{L}}{\\partial S}.\n\\]\n\nThese expressions show that gradients propagate from the output back through the softmax, then through the scaled dot‑product, reaching the original query, key, and value matrices.\n\n### Effect of mask matrices\n\nIn tasks such as language modeling we apply a mask \\(M\\) (e.g., causal mask) before softmax:\n\n\\[\n\\alpha = \\text{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}} + M\\right)\n\\]\n\nwhere \\(M_{ij} = 0\\) for allowed positions and \\(-\\infty\\) for prohibited ones. Adding \\(-\\infty\\) forces the corresponding softmax entry to zero, effectively removing those tokens from the attention distribution. The mask therefore shapes the probability mass without breaking differentiability, because the softmax gradient is still defined for the remaining finite entries.'),
#   (3,
#    '## A Minimal PyTorch Implementation (MWE)\n\nBelow is a self‑contained, runnable sketch that shows the core of scaled‑dot‑product self‑attention without any extra bells‑and‑whistles.\n\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\nimport math\n\nclass SimpleSelfAttention(nn.Module):\n    """Scaled‑dot‑product self‑attention for a single head."""\n    def __init__(self, embed_dim):\n        super().__init__()\n        # 1️⃣ Linear projections for Q, K, V\n        self.q_proj = nn.Linear(embed_dim, embed_dim, bias=False)\n        self.k_proj = nn.Linear(embed_dim, embed_dim, bias=False)\n        self.v_proj = nn.Linear(embed_dim, embed_dim, bias=False)\n        self.scale = math.sqrt(embed_dim)\n\n    # 2️⃣ Compute Q·Kᵀ, optional mask, and softmax\n    def forward(self, x, mask=None):\n        """\n        x:   (batch, seq_len, embed_dim)\n        mask: (batch, seq_len) with 0 for padding positions (optional)\n        """\n        Q = self.q_proj(x)                # (B, L, D)\n        K = self.k_proj(x)                # (B, L, D)\n        V = self.v_proj(x)                # (B, L, D)\n\n        # (B, L, D) @ (B, D, L) -> (B, L, L)\n        scores = torch.matmul(Q, K.transpose(-2, -1)) / self.scale\n\n        if mask is not None:\n            # mask shape broadcastable to (B, L, L)\n            scores = scores.masked_fill(mask.unsqueeze(1) == 0, float(\'-inf\'))\n\n        attn_weights = F.softmax(scores, dim=-1)   # (B, L, L)\n\n        # 3️⃣ Weighted sum of V\n        out = torch.matmul(attn_weights, V)        # (B, L, D)\n        return out, attn_weights\n```\n\n### Validation against `torch.nn.MultiheadAttention`\n\n```python\nbatch, seq_len, dim = 2, 5, 8\nx = torch.randn(batch, seq_len, dim)\n\n# Our implementation\nsimple_attn = SimpleSelfAttention(dim)\nout_simple, _ = simple_attn(x)\n\n# Reference implementation (single head)\nmha = nn.MultiheadAttention(embed_dim=dim, num_heads=1, bias=False, batch_first=True)\n# Initialise MHA with the same linear weights for a fair comparison\nmha.in_proj_weight.data = torch.cat([simple_attn.q_proj.weight,\n                                    simple_attn.k_proj.weight,\n                                    simple_attn.v_proj.weight], dim=0)\n\nout_ref, _ = mha(x, x, x)   # (B, L, D)\n\n# Numerical check\nprint("Close?", torch.allclose(out_simple, out_ref, atol=1e-6))\n```\n\nThe script builds three `nn.Linear` layers, computes the scaled dot‑product, optionally masks padded tokens, normalises with softmax, and finally multiplies the attention scores by the value tensor. Wrapping everything in a `nn.Module` makes it drop‑in compatible with the rest of a model pipeline. The validation block confirms that the custom implementation reproduces the output of PyTorch’s native `MultiheadAttention` (with a single head) to machine precision, giving you confidence that the core math is correct while keeping the code easy to read and extend.'),
#   (4,
#    '## Multi‑Head Attention: Extending the Primitive\n\nSplitting the hidden dimension **D** into *h* separate heads (each of size **d = D / h**) lets the model attend to different sub‑spaces of the representation simultaneously. One head might focus on syntactic relations while another captures long‑range semantic dependencies. By learning distinct query/key/value projections per head, the network can discover a richer set of patterns than a single, monolithic attention matrix could express.\n\n**Step‑by‑step flow**\n\n1. **Linear projections per head** – The input tensor **X** ∈ ℝ<sup>B×T×D</sup> is multiplied by three learned weight matrices **W<sub>Q</sub>**, **W<sub>K</sub>**, **W<sub>V</sub>** and reshaped to (B, T, h, d).  \n2. **Independent attention** – For each head *i*, compute scaled dot‑product attention using its own Q<sub>i</sub>, K<sub>i</sub>, V<sub>i</sub>. This yields head outputs **O<sub>i</sub>** ∈ ℝ<sup>B×T×d</sup>.  \n3. **Concatenation** – Stack the *h* outputs along the head dimension, producing **O** ∈ ℝ<sup>B×T×(h·d)</sup> = ℝ<sup>B×T×D</sup>.  \n4. **Final linear projection** – Apply a weight matrix **W<sub>O</sub>** ∈ ℝ<sup>D×D</sup> to map the concatenated tensor back to the original hidden size.\n\n```\nX (B,T,D)\n │ split → (B,T,h,d)\n │─► Q,K,V per head\n │─► attention_i → O_i (B,T,d)\n └─► concat → O (B,T,D)\n      │\n      └─► W_O → Y (B,T,D)\n```\n\n**Head‑specific hyper‑parameters**  \nEach head can have its own dropout rate, allowing finer regularisation of noisy patterns. When heads are expected to learn highly distinct behaviours (e.g., multi‑modal inputs), independent projections are preferred. Conversely, sharing **W<sub>Q</sub>**, **W<sub>K</sub>**, **W<sub>V</sub>** across heads reduces parameter count and can be useful for small models or when training data is limited.\n\n**Practical tricks**\n\n- Use `torch.nn.MultiheadAttention` to handle all projections, masking, and dropout internally.  \n- Pad sequences to the same length and supply an attention mask so the module correctly ignores padding tokens.  \n- For inference, cache the key and value tensors after the first pass; subsequent steps only need to compute new queries, drastically reducing latency in autoregressive generation.'),
#   (5,
#    '## Performance and Cost Considerations\n\nSelf‑attention is attractive for its flexibility, but its computational profile scales quadratically with the input length. For a sequence of length **N** and hidden size **d**, the attention matrix requires **O(N²·d)** multiply‑adds and the same order of memory to store the Q·Kᵀ scores. In practice, the hidden dimension is often a multiple of the number of heads, so the constant factor can be large: a 512‑token sentence with **d = 768** already consumes several gigabytes of GPU memory during training.\n\nThe quadratic term means that **N** dominates both time and space. A quick profiling run on a V100 using `torch.autograd.profiler` illustrates this:\n\n- **N = 128** → forward pass ≈ 2\u202fms, ~0.6\u202fGB memory.  \n- **N = 512** → forward pass ≈ 15\u202fms, ~4\u202fGB memory.  \n- **N = 1024** → forward pass ≈ 55\u202fms, >8\u202fGB memory (out‑of‑memory on many cards).\n\nThe runtime increase is roughly proportional to **N²**, confirming that extending sequence length is the primary cost driver, far more than modest changes to **d**.\n\nWhen long sequences are required, low‑rank or sparse attention variants become attractive:\n\n- **Linformer** projects keys and values to a fixed‑size low‑dimensional space, reducing complexity to **O(N·d·k)** where *k* ≪ *N*. Works well when global context can be approximated by a small set of learned bases.  \n- **Performer** replaces the softmax with a kernel that enables linear‑time attention via random feature mappings. Effective for very long inputs (thousands of tokens) where exact softmax is unnecessary.  \n\nBoth methods trade a small amount of accuracy for orders‑of‑magnitude speed‑ups, especially in encoder‑only models or retrieval‑augmented pipelines.\n\nHardware‑level optimizations further shrink latency. Mixed‑precision training (FP16 or BF16) halves the memory footprint of Q, K, V tensors and allows Tensor Cores to execute the matrix multiplications at peak throughput. Kernel fusion—combining the Q·Kᵀ multiplication, scaling, and softmax into a single GPU kernel— eliminates intermediate memory writes and reduces launch overhead.\n\n**Rule‑of‑thumb for head count and hidden size:**  \nGiven a FLOPs budget **B**, allocate **h** heads such that each head’s dimension **dₕ = d / h** stays ≥\u202f32 to preserve representation power. Solve  \n\n\\[\nB \\approx 2 \\times N^{2} \\times d \\approx 2 \\times N^{2} \\times h \\times d_{h}\n\\]\n\nfor **h**, then pick the largest **h** that yields **dₕ ≥ 32**. For example, with **B = 10⁹ FLOPs**, **N = 256**, and **d = 768**, the calculation suggests **h ≈ 12** (giving **dₕ = 64**), a common configuration that balances parallelism and cost. Adjust **h** downward if memory constraints tighten, or increase **dₕ** when higher expressiveness is needed.'),
#   (6,
#    '## Debugging and Observability Tips for Self‑Attention\n\nDiagnosing problems in attention‑based models often requires looking inside the matrix operations that drive the mechanism. The following checklist gives developers concrete ways to surface hidden bugs and performance issues.\n\n- **Log the attention weight matrix and visualize it as a heatmap**  \n  Export the raw attention scores (after softmax) for a few representative batches and plot them with a library such as Matplotlib or Seaborn. A heatmap makes it easy to spot uniform attention (all rows look alike), overly sharp peaks, or missing diagonal patterns that indicate a masking error. Compare the visual against expected patterns for the task (e.g., causal models should show a lower‑triangular structure).\n\n- **Use gradient‑norm checks on Q, K, V**  \n  Compute the L2 norm of the gradients flowing into the query, key, and value tensors after a backward pass. Very small norms suggest vanishing signals, while exploding norms point to instability in the scaling factor or learning rate. Logging these norms per layer helps you pinpoint where the gradient flow breaks down.\n\n- **Insert unit tests that verify mask handling**  \n  Write tests that feed known input sequences with explicit padding and causal masks, then compare the resulting attention matrices against a hand‑computed reference (e.g., using NumPy). Assertions on both the masked entries (should be zero) and the unmasked distribution catch off‑by‑one errors in mask construction.\n\n- **Leverage `torch.nn.utils.checkpoint` to isolate memory‑related crashes**  \n  Wrap large attention blocks with checkpointing to trade compute for reduced memory usage. When a crash occurs, you can selectively enable or disable checkpointing on specific layers to identify which part of the forward pass exceeds GPU memory limits.\n\n- **Apply attention‑rollout or attribution techniques**  \n  Methods like attention‑rollout aggregate attention across layers to produce a single relevance map for each output token. Visualizing this map reveals which input tokens the model actually attends to, helping you detect whether irrelevant tokens dominate the decision or whether important tokens are being ignored.')],
#  'final': '# Demystifying Self‑Attention: Theory, Code, and Practical Tips\n\n## What Self‑Attention Is and Why It Matters\n\nTraditional recurrent networks pass a hidden state sequentially, so information from token\u202f*i* reaches token\u202f*j* only after *i\u202f→\u202fi+1\u202f→\u202f…\u202f→\u202fj* steps. Convolutional layers aggregate locally with a fixed receptive field; distant tokens influence each other only after many stacked layers. Self‑attention removes both constraints: every token can directly read a weighted sum of all other token representations in a single layer, providing a global receptive field with constant depth.\n\nThe mechanism is often described with the **query‑key‑value** metaphor. For each token we compute three vectors—*query*\u202f*Q*, *key*\u202f*K*, and *value*\u202f*V*—by linear projections of the same embedding. The attention weight between token\u202f*i* and token\u202f*j* is proportional to the similarity of *Q₍i₎* and *K₍j₎* (typically a scaled dot‑product). Multiplying these weights by the corresponding *V₍j₎* and summing yields the output for token\u202f*i*, meaning each token attends to every other token.\n\n```mermaid\ngraph LR\n    Input[Input Embeddings] -->|Linear proj.| Q[Queries]\n    Input -->|Linear proj.| K[Keys]\n    Input -->|Linear proj.| V[Values]\n    Q -->|Dot‑product| Sim[Similarity Matrix]\n    K -->|Dot‑product| Sim\n    Sim -->|Softmax| Weights[Attention Weights]\n    Weights -->|Weighted sum| O[Attention‑Weighted Output]\n    V --> O\n    O --> Output[Next Layer Input]\n```\n\nSelf‑attention quickly became the backbone of modern models. In **language modeling**, Transformers replace RNNs to capture long‑range dependencies, enabling large‑scale text generation. **Vision Transformers** treat image patches as tokens, achieving state‑of‑the‑art classification and detection without convolutions. **Graph neural networks** such as Graph Attention Networks use attention to weigh neighboring node features, improving relational reasoning on irregular structures.\n\n## Scaled Dot‑Product Self‑Attention: The Mathematics\n\nThe heart of the Transformer’s attention mechanism is the **scaled dot‑product** operation:  \n\n\\[\n\\text{Attention}(Q, K, V) = \\text{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}}\\right)V\n\\]\n\nwhere \\(Q\\in\\mathbb{R}^{n\\times d_k}\\), \\(K\\in\\mathbb{R}^{n\\times d_k}\\), and \\(V\\in\\mathbb{R}^{n\\times d_v}\\) are the query, key, and value matrices for a sequence of \\(n\\) tokens, and \\(d_k\\) is the dimensionality of the key/query vectors.\n\n### Why scale by \\(\\sqrt{d_k}\\)?\n\nEach entry of \\(QK^{\\top}\\) is a sum of \\(d_k\\) products of independent random variables. Its variance grows linearly with \\(d_k\\). Without scaling, large \\(d_k\\) push the dot‑product magnitudes into a region where the softmax saturates (extreme values → near‑zero gradients). Dividing by \\(\\sqrt{d_k}\\) normalizes the variance to roughly 1, keeping the softmax inputs in a regime where gradients remain stable and training converges faster.\n\n### Softmax as a probability distribution\n\nThe softmax transforms the scaled scores \\(s_{ij} = (QK^{\\top})_{ij}/\\sqrt{d_k}\\) into non‑negative weights that sum to one:\n\n\\[\n\\alpha_{ij} = \\frac{\\exp(s_{ij})}{\\sum_{l=1}^{n}\\exp(s_{il})}\n\\]\n\nThus each row \\(\\alpha_i\\) is a categorical distribution over all tokens, indicating how much token \\(i\\) attends to token \\(j\\). Because softmax is differentiable everywhere, gradients can flow from the loss back through the attention weights to \\(Q\\), \\(K\\), and \\(V\\).\n\n### Gradient flow\n\nLet \\(A = \\text{softmax}(S)V\\) with \\(S = QK^{\\top}/\\sqrt{d_k}\\). For a loss \\(\\mathcal{L}\\),\n\n\\[\n\\frac{\\partial \\mathcal{L}}{\\partial V} = \\alpha^{\\top}\\frac{\\partial \\mathcal{L}}{\\partial A},\n\\qquad\n\\frac{\\partial \\mathcal{L}}{\\partial S} = \\left(\\frac{\\partial \\mathcal{L}}{\\partial A}V^{\\top}\\right) \\odot \\alpha  ...
